# %% [markdown]
# Sea una sucesión cuyos tres primeros términos son 200, 224 y 248. Si la sucesión
# mantiene el mismo patrón de crecimiento sucesivamente.
#
# ***Pregunta 1***
# El valor del término que ocupa el lugar 36 en esta sucesión es

# %%
a1=200
a2=224
a3=248
d1=224-200
d2=248-224
print(f"d1={d1}\nd2={d2}\nd=24")
d=24 # Es una S.A. ya que tenemos una diferencia constante entre términos consecutivos.
a36=a1+(36-1)*d 
print(f"el a36={a36} ")
# Out:
# d1=24
# d2=24
# d=24
# el a36=1040

# %% [markdown]
# ***Pregunta 2***
# ¿Cuál es la suma de los primeros 36 términos de esta sucesión?

# %%
suma=[]
def a(n):
    return 200+(n-1)*d
for i in range(1,37):
    suma.append(a(i))
print(f"La suma es {sum(suma)}")
# Out:
# La suma es 22320

# %% [markdown]
# Con el siguiente contexto responda las Pregunta 3 y Pregunta 4.
#
# Una cuenta de ahorros proporciona un interés mensual del 1,2%. La cuenta se abre con $2.000.000. En este contexto, se define $a_n$ como el saldo en pesos que presenta esta cuenta de ahorros transcurridos $n$ meses.

# %% [markdown]
# ***Pregunta 3***
# La expresión algebraica que permite calcular cada término de la sucesión $a_n$ es:

# %%
a0=2000000 
r=1.012 #100%+1.2% = 101.2%=1.012
#a_n=a1*R**(n-1)  o bien, a_n=a0*R**(n) #NOTAR QUE ESTÁ EN FUNCIÓN DEL TÉRMINO 0
a1=a0*r
print(a1)
# Out:
# 2024000.0

# %% [markdown]
# ***Pregunta 4***
# El saldo aproximado, en la cuenta de ahorros al cabo de 9 meses será:

# %%
a9=a1*r**(9-1)
print(a9)

a92=a0*r**(9)
print(round(a92))
# Out:
# 2226663.5926818973
# 2226664

# %% [markdown]
# Con el siguiente contexto responda las Pregunta 5 y Pregunta 6.
# Una empresa de tecnología está optimizando sus servidores. Para ello, mide cada mes las transacciones por segundo (TPS) de sus servidores. Se ha obtenido que el segundo mes, el rendimiento del servidor es 1.066 TPS y el quinto mes, el rendimiento es de 8.528 TPS.

# %% [markdown]
# ***Pregunta 5***
# Si el rendimiento de los servidores crece a razón constante, ¿cuál es el rendimiento de un servidor el noveno mes?

# %%
a2=1066
a5=8528
r=(a5/a2)**(1/3)
a1=a5*r**(-4)
print(f"a1={a1}\nr={r}")
def a(n):
    return a1*r**(n-1)
print(f"El rendimiento del 9no mes es {a(9)} TPS")
# Out:
# a1=533.0
# r=2.0
# El rendimiento del 9no mes es 136448.0 TPS

# %% [markdown]
# ***Pregunta 6***
# Si el rendimiento de los servidores crece a razón constante, ¿en qué mes el rendimiento de un servidor es de 34.112 TPS?

# %%
an=0
i=0
while an<34112:
    i+=1
    an=a(i)
print(f"En el mes de lugar {i}")
#comprobando:
a7=a(7)
print(a7)


#Resolviendo usando ecuaciones:
a2=1066
a5=8528
r=(a5/a2)**(1/3)
a1=a5*r**(-4)
def a(n):
    return a1*r**(n-1)

import sympy as sp
n=sp.Symbol("n")
ecuacion=a(n)-34112
solucion=sp.solve(ecuacion,n)
print(f"En en mes de lugar {round(solucion[0])}")
# Out:
# En el mes de lugar 7
# 34112.0
# En en mes de lugar 7

# %% [markdown]
# ***Pregunta 7***
# Un local comercial se arrendó por 2 años y durante ese periodo, el valor del arriendo se incrementó todos los meses en una cantidad constante. En el cuarto mes, el valor del arriendo fue $1.108.000 y en el décimo segundo mes el valor del arriendo fue $1.396.000.

# %%
#Incremento en una cantidad constante corresponde a una S.A.
a4=1108000
a12=1396000
d=(a12-a4)/8
a1=a4+(1-4)*d #o bien a1=10-9d
print(f"la diferencia es entre cada término consecutivo es {d}")
print(f"el valor del primer mes es {a1}")

def a(n):
    return a1+(n-1)*d

af=1828000
an=0
i=0
while an<af:
    i+=1
    an=a(i)
print(f"el lugar es {i}")
#comprobando:
a24=a(24)
print(a24)


#Resolviendo usando ecuaciones:
import sympy as sp
n=sp.Symbol("n")
ecuacion=a(n)-1828000
solucion=sp.solve(ecuacion,n)
print(f"El lugar es {round(solucion[0])}")
# Out:
# la diferencia es entre cada término consecutivo es 36000.0
# el valor del primer mes es 1000000.0
# el lugar es 24
# 1828000.0
# El lugar es 24

# %% [markdown]
# ***Pregunta 8***
#
# Una compañía que fabrica paneles solares tiene 2 plantas de producción y 3 bodegas de almacenamiento.
#
# La matriz $T_{ij}$ representa las unidades producidas mensualmente en la planta $i$ y que son transportadas a la bodega $j$ para ser almacenadas durante su respectivo mes de producción.
# ![image.png](attachment:image.png)
#
# Por otra parte, la matriz $U_{ij}$ representa el costo (en pesos) de almacenar 1 unidad de este producto durante el mes $j$ (enero y febrero) en la bodega $i$.
# ![image-2.png](attachment:image-2.png)
#
# ¿Cuánto dinero costó almacenar los paneles de la planta 2 en el mes de febrero?

# %%
#T2x3 : filas: plantas; columnas: bodegas
#U3x2 : filas: bodegas: columnas: mes
import numpy as np
T=np.array([[300,372,240],[260,180,324]])
U=np.array([[1200,1250],[1100,1400],[1350,1200]])

R=T.dot(U) #matriz T*U ; R2x2: filas plantas, columnas: meses
print(R)
#planta 2 en febrero: r22
print(f"En el mes de febrero almacenar toda la producción de la planta 2 costó {R[2-1,2-1]} pesos")
# Out:
# [[1093200 1183800]
#  [ 947400  965800]]
# En el mes de febrero almacenar toda la producción de la planta 2 costó 965800 pesos

# %% [markdown]
# Con la información que se presenta a continuación, responda las preguntas 9, 10 y 11, indicando si las afirmaciones son verdaderas o falsas y la pregunta 12.
#
# Una empresa vende 4 modelos de 3 productos computacionales diferentes. Las matrices $S_{ij}$ y $C_{ij}$ que se muestran a continuación, representan las cantidades producidas mensualmente del producto i y modelo j en dos plantas de la empresa; Santiago y Concepción respectivamente.
# ![image.png](attachment:image.png)

# %% [markdown]
# ***Pregunta 9***
#
# Si la matriz A representa la producción mensual total de las dos plantas de esta empresa, entonces, el elemento $a_12$ corresponde a la cantidad de unidades del producto 1 y del modelo 2, que se produjeron en ambas plantas durante un mes.
#
# Indique si la afirmación anterior es VERDADERA o FALSA.
#
# S3x2: filas: productos    columnas: modelos planta Santiago
#
# C3x2: filas: productos    columnas: modelos planta Concepción
#
# a12: fila1: producto1 ; columna 2: modelo 2.
#
# ***RESPUESTA:***
# La afirmación es verdadera

# %% [markdown]
# ***Pregunta 10***
# La matriz S por C muestra la producción total mensual de ambas plantas, de cada producto con cada modelo.
#
# ***RESPUESTA:***
# La afirmación es falsa, primero porque las matrices no son compatibles para multiplicarse (S3x4 y C3x4), segundo, para obtener la producción total entre ambas plantas, basta con sumar las matrices.

# %% [markdown]
# ***Pregunta 11***
#
# La fila 2 de la matriz S más C corresponde a la producción total mensual del producto 2 de los 4 modelos en ambas plantas.
#
# ***RESPUESTA:***
# La afirmación es verdadera, ya que al sumar los elementos de la fila 2, tenemos el total mensual del producto 2 en las 4 modelos.

# %% [markdown]
# ***Pregunta 12***
#
# Para el próximo mes, se proyecta que en Santiago la producción se reducirá en un 20%, y en Concepción aumentará un 10%.
# Si la matriz T representa la producción mensual total de la empresa proyectada para el siguiente mes, la producción estimada para el modelo 3 del producto 2 será de ****** unidades.

# %%
S=np.array([[360,280,150,420],[450,370,210,130],[240,260,320,340]])
C=np.array([[130,310,230,280],[270,240,520,370],[190,290,460,410]])
T=0.8*S+1.1*C
print(f"La matriz T:\n{T}")
#modelo 3 del producto 2 :  t23
t23=T[2-1,3-1]
print(f"será de {t23} unidades")
# Out:
# La matriz T:
# [[431. 565. 373. 644.]
#  [657. 560. 740. 511.]
#  [401. 527. 762. 723.]]
# será de 740.0 unidades

# %%
#PRGUNTA 13: El valor de C=A*B
import numpy as np
A=np.fromfunction(lambda i,j: 2*(i+1)+3*(j+1),(3,3))
B=np.fromfunction(lambda i,j: 10*(i+1)*(j+1),(3,3))

C=A.dot(B)
print(C)
# Out:
# [[ 540. 1080. 1620.]
#  [ 660. 1320. 1980.]
#  [ 780. 1560. 2340.]]

# %% [markdown]
# ***Pregunta 14***
# Una empresa de desarrollo de software está diseñando una aplicación para optimizar el uso de servidores en la nube.
# Dos servicios principales se ejecutan en paralelo en cada servidor: Servicio A y Servicio B. Cada uno consume una
# cantidad de recursos en términos de CPU y memoria, que varía según el tiempo de ejecución.
#
# El sistema de ecuaciones que se plantea a continuación, permite determinar los minutos " x " destinados al ejecutarse
# el Servicio A y los minutos " y " destinados al ejecutarse el Servicio B, en cada servidor:
#
# ![image.png](attachment:image.png)
#
# ¿Cuántos minutos debe ejecutarse el Servicio A en cada servidor?

# %%
A=np.array([[2,1],[3,-2]])
B=np.array([[10],[8]])
Ainv=np.linalg.inv(A)
X=Ainv.dot(B)
print(f"x={round(X[0,0])}\ny={round(X[1,0])}")
print(f"Debe ejecutarse durante 4 minutos en cada servidor")
# Out:
# x=4
# y=2
# Debe ejecutarse durante 4 minutos en cada servidor

# %% [markdown]
# Con la información que se presenta a continuación, responda las preguntas 15, 16, 17, 18 y 19, indicando si las afirmaciones son verdaderas o falsas.
#
#
#
# Respecto a la matriz A dada por:
#
# ![image.png](attachment:image.png)

# %%
A=np.array([[2,3],[1,2]])
#Pregunta 15: La  matriz es cuadrada, ya que tiene misma cantidad de filas que columnas

#PREG 16:
A_inv=np.linalg.inv(A)
print(f"A_inv=\n{A_inv}")
#PREG 17:
AT=A.T
print(f"AT=\n{AT}")
#PREG18:
# A es de 2x2

#PREG19:
S=A+AT
print(f"S=\n{S}")
# Out:
# A_inv=
# [[ 2. -3.]
#  [-1.  2.]]
# AT=
# [[2 1]
#  [3 2]]
# S=
# [[4 4]
#  [4 4]]

# %% [markdown]
# Pregunta 20
# 1
#  punto
# Pregunta 20
# Una empresa de tecnología utiliza dos tipos de software, Software A y Software B, para procesar solicitudes de dos tipos de aplicaciones: Aplicaciones Web y Aplicaciones de Base de Datos. Cada software puede procesar solicitudes en ambos tipos de aplicaciones, con las siguientes características:
#
# El Software A puede procesar, cada minuto, hasta 2 solicitudes de Aplicaciones Web y 1 solicitud de Aplicación de Base de Datos.
# El Software B puede procesar, cada minuto, hasta 3 solicitudes de Aplicaciones Web y 4 solicitudes de Aplicaciones de Base de Datos.
# La empresa requiere procesar en total 52 solicitudes de Aplicaciones Web y 56 solicitudes de Aplicaciones de Base de Datos.
#
# Para modelar esta situación, se define:
#
# ﻿x﻿: los minutos que el Software A estará operando.
# ﻿y﻿: los minutos que el Software B estará operando.
# El sistema de ecuaciones que representa el requerimiento de procesamiento de la empresa es:
# ![image.png](attachment:image.png)
#
# ¿Cuántos minutos deben estar operando el Software A y el Software B para cumplir con los requerimientos de procesamiento de solicitudes?

# %%
A=np.array([[2,3],[1,4]])
B=np.array([[52],[56]])
Ainv=np.linalg.inv(A)
X=Ainv.dot(B)
print(f"x={round(X[0,0])}\ny={round(X[1,0])}")
print(f"Deben operar durante 8 y 12 minutos")
# Out:
# x=8
# y=12
# Deben operar durante 8 y 12 minutos
