# %%
import numpy as np

A = np.array([[36,56],[12,38]])
B = np.array([[28940],[14480]])

A_inv = np.linalg.inv(A)
Y = A_inv.dot(B)
print(Y)
#Comprobar
print(36 * 415 + 56*250)
print(12 * 415 + 38*250)

# %% [markdown]
# ¿Cuál es el precio de un asiento en clase A?
# - El precio de un asiento en clase A es de 415 dólares
