# %% [markdown]
# # Problema 1

# %% [markdown]
# Una red transmite datos a $100$ megabits por segundo. Crea una función utilizando *Python* que permita calcular la cantidad de datos transmitidos en una cierta cantidad de tiempo (en segundos). Luego utiliza la función y calcula cuántos datos se transmiten en:
#
# * $45$ segundos
# * $1,5$ minutos
# * $1$ hora

# %%
#Variable independiente: tiempo(segundos)
#Variable dependiente: cantidad de datos transmitidos (megabits)
#Dominio contextualizado: desde cero al infinito ; [0, infinito[
def D(tiempo : float):
    cantidad = (100 * tiempo)
    return cantidad
print(f'{D(45)} Bits')
print(f'{D(1.5*60)} Bits')
print(f'{D(1*60*60)} Bits')

# %% [markdown]
# # Problema 2

# %% [markdown]
# Utilizando la función definida en el problema $1$, genera un listado que muestre los datos transmitidos para tiempos desde $0$ hasta $1.000$ segundos con incrementos de $100$ segundos.

# %%
def D(tiempo : float):
    cantidad = (100 * tiempo)
    return cantidad
lista = []
for i in range(0,1001,100):
    lista.append(D(i))
print(lista)
# Out:
# [0, 10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000]

# %% [markdown]
# # Problema 3

# %% [markdown]
# La **latencia** de una red corresponde al tiempo que tarda un paquete de datos en viajar desde el punto de origen al destino. En otras palabras, es el tiempo que transcurre desde que se envía una solicitud de un dispositivo hasta que se recibe una respuesta del servidor u otro dispositivo.
#
# La latencia puede verse afectada por la velocidad de transmisión de los datos a través de los cables o conexiones inalámbricas, la distancia física entre los dispositivos, el tiempo que tarda un computador en procesar o reenviar los datos, etc.
#
# En redes de comunicación, como las videoconferencias, juegos en línea y transmisión de datos en tiempo real, es deseable una baja latencia, de lo contrario pueden existir retrasos en la comunicación y afectar negativamente la experiencia del usuario.

# %% [markdown]
# Según el contexto mencionado, crea una función en *Python* que permita calcular la **latencia real** de una red dada una latencia estimada. Suponga que la latencia real es un $20\%$ mayor a la latencia estimada.
#
# Calcule la latencia real para una latencia estimada de:
#
# a)   $200$ milisegundos.
#
# b)   $149$ milisegundos.
#
# c)   $74$ milisegundos.

# %%
def L(tiempo:int): #L es de latencia_real
    latancia_real = (tiempo*120)/100 #1.2,1
    return latancia_real
print(f'latencia real: {L(200)}')
print(f'latencia real: {L(149)}')
print(f'latencia real: {L(74)}')
# Out:
# latencia real: 240.0
# latencia real: 178.8
# latencia real: 88.8

# %% [markdown]
# # Problema 4

# %% [markdown]
# Como parte de un proyecto de mejora, en el año $2021$ se instaló un cable de fibra óptica que une España con EEUU. El cable tiene un largo de $6.600$ $km$ y fue colocado por un barco a una velocidad de $1,85$ $km/h$.
#
#
#
# 1.   Determine la forma algebraica de la función que permite determinar el largo del cable instalado (en km) a partir del tiempo transcurrido (en horas). Utilice la instrucción *def* para definir la función en *Python*.
# 2.   Defina variable dependiente e independiente, indicando unidad de medida.
# 3.   Determine el dominio contextualizado de la función.
# 4.   Grafique la función utilizando la biblioteca *Matplotlib* considerando el dominio contextualizado.
# 5.   ¿Cuántos metros de cable se instalaron al transcurrir $148$ horas? ¿Y transcurridas $2.300$ horas?
# 6.   Si se han instalado $3.480$ kilometros de cable, ¿cuántas horas llevan de trabajo?
# 7.   ¿Cuánto tiempo transcurrió para que se completara la obra?

# %% [markdown]
# 1.   Determine la forma algebraica de la función que permite determinar el largo del cable instalado (en km) a partir del tiempo transcurrido (en horas). Utilice la instrucción *def* para definir la función en *Python*.
# Forma algeraica: f(x)=1,85*x "x: es el tiempo

# %%
def L(t):
    L = 1.85*t
    return L
print(L(148))
# Out:
# 273.8

# %% [markdown]
# 2.   Defina variable dependiente e independiente, indicando unidad de medida.
# variable dependiente: largo de cable instalado (km)
# variable independiente: tiempo (horas)

# %% [markdown]
# 3.   Determine el dominio contextualizado de la función.
# recuerde que el dominio contextualizado está asociado a la variable indendiente y el contexto
# dominio contextualizado: desde 0 hasta 3568 horas, aproximadamente (6600/1.85)
# dom contextualizado: [0,3568]

# %%
# 4.   Grafique la función utilizando la biblioteca *Matplotlib* considerando el dominio contextualizado.
import matplotlib.pyplot as plt
import numpy as np #para graficar necesito esas dos librerias

def f(x):
    f = 1.85*x
    return f
x = np.arange(0,3568,1) #paso de 1
plt.plot(x,f(x), label='f')
plt.title('Largo del cable en funcion del tiempo')
plt.xlabel('Tiempo transcurrido en horas')
plt.ylabel('largo del cable en km')
plt.grid()
plt.legend()
plt.plot(148,f(148), 'ro', color = 'black')
plt.plot(2300,f(2300), marker = 'o', color = 'black')
#opcional modificar ejes (centrarlos)
ax = plt.gca()
ax.spines[['left', 'bottom']].set_position(('data',0))
ax.spines[['right','top']].set_visible(False)
plt.show()
# Out:
# C:\Users\Cetecom\AppData\Local\Temp\ipykernel_3456\4118041849.py:15: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(148,f(148), 'ro', color = 'black')

# %%
#5.   ¿Cuántos metros de cable se instalaron al transcurrir $148$ horas? ¿Y transcurridas $2.300$ horas?
print(f'Al transcurrir 148 horas se han instalado {f(148)}km de cable')
print(f'Al tran{f(2300)}')
# Out:
# Al transcurrir 148 horas se han instalado 273.8km de cable
# Al tran4255.0

# %%
#6.   Si se han instalado $3.480$ kilometros de cable, ¿cuántas horas llevan de trabajo?
#REVISAR
import sympy as sp

def L(t):
    L = 1.85*t
    return L

x = sp.Symbol("X")
ecuacion = L(x) - 3480
solucion = sp.solve(ecuacion, x) #resuelva la ecucacion con respecto a x
print(f'Al transcurrir: {round(solucion[0],1)} horas se han instalado 3480km de cable ')
# Out:
# Al transcurrir: 1881.1 horas se han instalado 3480km de cable

# %% [markdown]
# # Problema 5

# %% [markdown]
# Un turista ha llegado a Santiago y desea conocer algunos lugares de la ciudad. Ha decidido visitar el Palacio de la Moneda y desde ahí trasladarse al centro comercial "Costanera Center", utilizando algún medio de transporte que ofrece la ciudad.
#
# Si se traslada en metro deberá abordar en estación La Moneda y bajar en la estación Tobalaba ($9$ estaciones). La función $f(t)$ permite calcular la distancia recorrida utilizando el metro (en kilómetros) transcurridos $t$ minutos.
#
# $$f(t) = 0,4t$$
#
# Si se traslada en bus, el turista podrá observar la ciudad y otros atractivos en su viaje. La función $g(t)$ permite calcular la distancia recorrida en bus (en kilómetros) transcurridos $t$ minutos.
#
# $$g(t) = 0,3t$$
#
# Según la información anterior:
#
# 1. Grafique ambas funciones, indicando el nombre de cada eje junto con su unidad de medida. Para realizar el gráfico utilice la biblioteca *Matplotlib*.
# 2.  Si se sabe que el metro se demora $1,2$ minutos en llegar desde una estación a otra y espera $30$ segundos en cada estación, indique el dominio contextualizado para $f(t)$.
# 3. Mediante análisis gráfico, indique cuál medio de transporte es más conveniente en términos de tiempo, para el turista. Justifique.
# 4.  Si se sabe que desde estación La Moneda hasta Tobalaba son aproximadamente $6$ kilómetros ¿cuántos tiempo tardará el turista en llegar a su destino con cada una de las opciones?

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(t):
    f = 0.4*t
    return f

def g(t):
    g = 0.3*t
    return g

#De cuanto en cuanto aumenta el grafico
x = np.arange(0,20,1) #paso de 1
#GRAFICACION
plt.plot(x,f(x), label='f(t)')
plt.plot(x,g(x), label='g(t)')
#TITULOS
plt.title('distancia recorrida en funcion del tiempo')
plt.ylabel('distancia [km]')
plt.xlabel('tiempo [minutos]')
#FORMATO cuadricula y activar las leyendas
plt.grid()
plt.legend()
#FORMATO posicionamiento de las lineas
ax = plt.gca()
ax.spines[['left', 'bottom']].set_position(('data',0))
ax.spines[['right','top']].set_visible(False)
plt.show()

#2.  Si se sabe que el metro se demora $1,2$ minutos en llegar desde una estación a otra y espera $30$ segundos en cada estación, indique el dominio contextualizado para $f(t)$.

"""
Dominio contextualizado: Desde 0  a 14,8
Dominio contextualizado: [0, 14,8] minutos
"""

#3. Mediante análisis gráfico, indique cuál medio de transporte es más conveniente en términos de tiempo, para el turista. Justifique.

"""
En base al grafico es mas conveniente el metro ya que avanza más km en menor tiempo
"""

#4.  Si se sabe que desde estación La Moneda hasta Tobalaba son aproximadamente $6$ kilómetros ¿cuántos tiempo tardará el turista en llegar a su destino con cada una de las opciones?

"""
En base al grafico , en bus son 15 minutos y en bus son 20 minutos 
"""
# Out:
# 1 22.0

# %% [markdown]
# # Problema 6

# %% [markdown]
# La temperatura de un servidor (en °C) puede ser modelada mediante la función
#
# $$T(t) = -0,5 t^{2} + 3 t + 20$$
#
# donde $t$ corresponde al tiempo transcurrido (en horas) en un día laboral. Considere que la jornada laboral comienza a las 08:00 horas y termina a las 17:00 horas.
#
# 1.  Defina variable dependiente e independiente, indicando unidad de medida.
#
# Variable dependiente: Termperatura de un servidor °C
# variable independiente: Tiempo transcurrido (Horas)
#
# 2.  Determine el dominio contextualizado del problema.
#
# Dominio contextualizado desde 0 hasta 9 o bien [0 , 9]
#
# 3.  Grafique la función utilizando *Python*.
# 4.  Mediante un análisis gráfico, estime cuándo el servidor alcanza la máxima temperatura y calcule cuánto es.
# 5.  Determine la temperatura del servidor a las 13:00 horas y al finalizar la jornada laboral.

# %%
import matplotlib.pyplot as plt
import numpy as np

def T(t):
    return -0.5 * t**2 + 3 * t + 20

x = np.arange(0 , 9.1 , 0.1) #esto define el rango, como vimos en el dominio de 0 a 9, lo mismo aqui
plt.plot(x,T(x), label = 'T(t)', color = 'purple') #label para el nombre de la funcion que en este caso es de T(t)
plt.plot(3,T(3) , marker ='o', color = '#AA1C47')
plt.title('Temperatura del servidor en funcion del iempo')
plt.xlabel('Tiempo (horas)') #independiente
plt.ylabel('Temperatura (°C)') #dependiente
plt.grid()
plt.legend()

plt.xlim(0 , 9)#depende del mismo dominio contextualizado limites del X
plt.ylim(0 , 25) #son los numeros que aparecen como limite en el Y

#modificador de spines
ax = plt.gca()
ax.spines[['left','bottom']].set_position(('data',0))
ax.spines[['right', 'top']].set_visible(False)
plt.show()

# %%
#4.  Mediante un análisis gráfico, estime cuándo el servidor alcanza la máxima temperatura y calcule cuánto es.
print(f'La temperatura máxima se alcanza a las 11AM y esta  es de {T(3)}°C')
# Out:
# La temperatura máxima se alcanza a las 11AM y esta  es de 24.5°C

# %%
#5.  Determine la temperatura del servidor a las 13:00 horas y al finalizar la jornada laboral.
print(f'La temperatura a las 13:00 horas es de {T(5)}°C')
print(f'La temperatura al finalizar el dia es de {T(9)}°C')
# Out:
# La temperatura a las 13:00 horas es de 22.5°C
# La temperatura al finalizar el dia es de 6.5°C

# %% [markdown]
# # Problema 7

# %% [markdown]
# El número de usuarios de una red social se puede modelar mediante la función:
#
# $$U(t) = \frac{1.000}{1+9e^{-0.5t}}$$
#
# donde $t$ corresponde al tiempo transcurrido en meses.
#
# 1.  Defina variable dependiente e independiente, indicando unidad de medida.
#
# variable dependiente: numero de usuario (Unidades)
# variable independiente: tiempo (Meses)
#
# 2.  Determine la cantidad de usuarios transcurridos $12$ meses.
# 3.  Grafique la función, utilizando la librería *Matplotlib*, para los primeros dos años de funcionamiento.
# 4.  ¿Cuánto tiempo debe pasar para que la red social llegue a $800$ usuarios?

# %%
import numpy as np
e = np.e
def U(t):
    return 1000/ (1+9*e**(-0.5*t))
print(f'La cantidad de usuarios transcurridos 12 meses es de {round(U(12))}')
# Out:
# La cantidad de usuarios transcurridos 12 meses es de 978

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.arange(0 , 24 , 0.1) #esto define el rango, como vimos en el dominio de 0 a 9, lo mismo aqui
plt.plot(x,U(x), label = 'U(t)', color = 'purple') #label para el nombre de la funcion que en este caso es de T(t)
#plt.plot(3,T(3) , marker ='o', color = '#AA1C47')
plt.title('Numero de usuarios en funcion del Tiempo en meses')
plt.xlabel('Tiempo (Meses)') #independiente
plt.ylabel('Numero de usuarios (unidades)') #dependiente
plt.grid()
plt.legend()

#plt.xlim(0 , 9)#depende del mismo dominio contextualizado limites del X
#plt.ylim(0 , 25) #son los numeros que aparecen como limite en el Y

#modificador de spines
ax = plt.gca()
ax.spines[['left','bottom']].set_position(('data',0))
ax.spines[['right', 'top']].set_visible(False)
plt.show()

# %%
#4.  ¿Cuánto tiempo debe pasar para que la red social llegue a $800$ usuarios?
#U(t) = 800 --> ecuacion = U(t) = 800
import sympy as sp
import numpy as np
#recordar que va en base a la funcion ya creada
e = np.e
#primero definir variable simbolica
t = sp.Symbol('t')
ecuacion = U(t) - 800 #es resultado por eso se le resta
solucion = sp.solve(ecuacion,t) #muestra una lista con la solucion de la ecuacion
print(f'para que la red social llegue a 800 usuarios es {round(solucion[0],1)} meses')
# Out:
# [7.16703787691221]
# para que la red social llegue a 800 usuarios es 7.2 meses

# %% [markdown]
# # Problema 8

# %% [markdown]
# El tiempo de ejecución de un algoritmo de ordenación (en segundos) se puede modelar mediante la función:
#
# $$A(n) = 0,01n^{2} + 0,5n + 2$$
#
# donde $n$ corresponde a la cantidad de elementos a ordenar. El algoritmo funciona desde las 23:00 horas hasta las 06:00 horas y debe ordenar $1.562$ elementos.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
#
# - Variable dependiente:Tiempo de ejecución (segundos) *lo que calcula la función*.
#
# - Variable independiente: Cantidad de elementos a ordenar en (unidades).
#
# 2. Determine el dominio contextualizado de la función.
#
# - dominio contextualizado: (asociado a la variable independiente) Desde 0 a 1562 o bien [0 , 1562].
#
# 3. Determine el tiempo de ejecución para ordenar $1.200$ elementos.
# 4. Grafique, utilizando la biblioteca *Matplotlib*, la función $A(n)$.
# 5. ¿Cuántos elementos ordena luego de $6$ horas de funcionamiento?

# %%
def A(n):
    return 0.01 * n**2 + 0.5*n + 2

print(f'El tiempo de ejecucion para 1200 elementos es {A(1200)} segundos {round(A(1200)/3600,1)} horas')
# Out:
# El tiempo de ejecucion para 1200 elementos es 15002.0 segundos 4.2 horas

# %%
#5. ¿Cuántos elementos ordena luego de 6 horas de funcionamiento?

import sympy as sp
#import numpy as np
def A(n):
    return 0.01 * n**2 + 0.5*n + 2
x = sp.Symbol('x')
ecuacion = A(x) - 21600 #6 horas = 21600 segundos (6*60*60 = 6*3600) funcion menos el resultado
solucion = sp.solve(ecuacion,x)# el resultado es una lista con la solucion
print(solucion)#da dos soluciones, una negativa y otra positiva porque es una ecuacion cuadratica (de grado 2)
print(f'La cantidad de elementos ordenados luego de 6 horas es {round(solucion[1])} elementos aproximadamente')
# Out:
# [-1494.83842649456, 1444.83842649456]
# La cantidad de elementos ordenados lsuego de 6 horas es 1445 elementos aproximadamente

# %% [markdown]
# # Problema 9

# %% [markdown]
# El consumo de energía (en $kWh$) de un *Data Center* puede ser modelado por la función:
#
#  $$E(t) = 50\cdot \log(t + 1) + 200$$
#
# donde $t$ corresponde al tiempo (en horas) desde el inicio del monitoreo.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
# - variable dependiente: consumo de energia en (kwH) #salida.
# - variable independiente: tiempo en horas.
# 2. Determine el consumo de energía del *Data Center* después de $5$ horas.
# 3. ¿Luego de cuántas horas el consumo será de $350$ kWh?
# 4. Grafique, utilizando la biblioteca *Matplotlib*, la función $E(t)$.

# %%
#graficar numpy
#para logaritmo log10() va a ser np.log10(t+1) con numpy
#para la ecuacion vamos a usar logaritmo de la mismal libreria sympy sp.log(argumento, base) sp.log(t+1,10)

import numpy as np
def E(t):
    return 50 * np.log10(t+1) + 200
print(f'El consumo de la energia despues de 5 horas es: {round(E(5),1)} kwH, aproximadamente')
# Out:
# El consumo de la energia despues de 5 horas es: 238.9 kwH, aproximadamente

# %%
import sympy as sp

def E(t):
    return 50 * sp.log(t+1,10) + 200

t = sp.Symbol("t")

ecuacion = E(t) - 350
print(ecuacion)

solucion = sp.solve(ecuacion, t)
print(solucion)
print(f'El consumo de energia llega a 350 kwH despues de {round(solucion[0])} horas, aproximadamente')
print(E(999))#para comprobar
# Out:
# 50*log(t + 1)/log(10) - 150
# [999]
# El consumo de energia llega a 350 kwH despues de 999 horas, aproximadamente
# 350

# %%
import matplotlib.pyplot as plt
import numpy as np
def E(t):
    return 50 * np.log10(t+1) + 200

x = np.arange(0 , 1000 , 0.1) #esto define el rango, como vimos en el dominio de 0 a 9, lo mismo aqui
plt.plot(x,E(x), label = 'E(t)', color = 'purple') #label para el nombre de la funcion que en este caso es de T(t)
plt.title('Consumo de energia en funcion del Tiempo ')
plt.xlabel('Tiempo en horas') #independiente
plt.ylabel('Consumo de energia en KWH') #dependiente
plt.grid()
plt.legend()

plt.xlim(0 , 1000)#depende del mismo dominio contextualizado limites del X
plt.ylim(0 , 400) #son los numeros que aparecen como limite en el Y

#modificador de spines
ax = plt.gca()
ax.spines[['left','bottom']].set_position(('data',0))
ax.spines[['right', 'top']].set_visible(False)
plt.show()

# %% [markdown]
# # Problema 10

# %% [markdown]
# En gestión de proyectos, es crucial entender cómo se distribuye la carga de trabajo a lo largo del tiempo para planificar recursos, tiempo y esfuerzos de manera eficiente. Un fenómeno común es la disminución exponencial de la carga de trabajo, donde el esfuerzo requerido es mayor al inicio del proyecto y disminuye gradualmente a medida que se completan las tareas principales.
#
# Esta disminución exponencial puede modelarse matemáticamente para predecir y gestionar el trabajo de manera efectiva.
#
# <br>
#
# Un estudio sobre gestión de proyectos sostiene que la carga de trabajo en un proyecto (en porcentaje) puede ser modelada por la función:
#
# $$W(t) = 100e^{-0.1t}$$
#
# donde $t$ corresponde al tiempo transcurrido (en semanas) desde el inicio del proyecto.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
#
# - Variable Independiente: Tiempo en semanas.
# - Variable Dependiente: carga de trabajo en % *lo que calcula la funcion*.
#
# 2. Determine la carga de trabajo al inicio del proyecto.
# 3. ¿Cuál será la carga de trabajo luego de transcurridas $4$ semanas desde el inicio del proyecto?
# 4. Si el proyecto duró $12$ semanas, ¿es correcto afirmar que la carga de trabajo llegó al $20\%$?
# 5. ¿Cuántas semanas han pasado desde el inicio del proyecto para que la carga de trabajo sea de $55\%$?
# 6. Utilizando *Matplotlib*, grafique la función considerando un tiempo máximo de $12$ semanas.

# %%
#2. Determine la carga de trabajo al inicio del proyecto.
import numpy as np
e = np.e
def W(t):
    return 100*e**(-0.1*t)
print(f'En la semana 1, es decir al inicio del proyecto, la carga será del {round(W(0),1)}%')
print(f'Luego de transcurrir 4 semanas, la carga será de {round(W(4))}%')
print(f'El porcentaje a las 12 semanas llegó a {round(W(12),1)}% por lo que no es preciso decir que la carga llegó al 20%')
# Out:
# En la semana 1, es decir al inicio del proyecto, la carga será del 100.0%
# Luego de transcurrir 4 semanas, la carga será de 67%
# El porcentaje a las 12 semanas llegó a 30.1% por lo que no es preciso decir que la carga llegó al 20%

# %%
import sympy as sp
def W(t):
    return 100*e**(-0.1*t)

x = sp.Symbol('x')
ecuacion = W(x) - 55
solucion = sp.solve(ecuacion,x)
print(f'Si la carga de trabajo es del 55% es porque han pasado {round(solucion[0]:.0f)}semanas')
# Out:
#   Cell In[13], line 8
#     print(f'Si la carga de trabajo es del 55% es porque han pasado {round(solucion[0]:0f)}semanas')
#                                                                          ^
# SyntaxError: f-string: expecting '=', or '!', or ':', or '}'
